# %%
# Test with a single sentence first
test_text = """On a narrow road between rice fields, a boy named Arjun walked home in the rain.
The storm had swallowed the sky, and the village lights were distant stars.
In his hand he carried a small lantern that flickered like a nervous firefly.
Arjun had found the lantern earlier that evening beside the old banyan tree.
No one in the village claimed it. Yet it burned with a steady golden glow,
as if it knew exactly where it needed to go.
The wind pushed against him, and the rain whispered endless stories in the dark.
But the lantern refused to go out. Whenever the wind grew stronger, the light
brightened, guiding his steps along the muddy path.
Halfway home Arjun noticed something strange. Wherever the lantern shone,
the puddles stopped looking like puddles. They looked like tiny mirrors,
each reflecting a different piece of the sky. One held a star, another a cloud,
another a faint silver moon.
He realized then that the lantern was not only lighting the road.
It was showing him how the world hides small wonders in ordinary places.
When Arjun finally reached home, the rain stopped. He turned around to look
at the lantern again, but the flame quietly faded, as if its job was finished.
The next morning the lantern was gone.
But whenever storms returned, Arjun walked the same road without fear.
Because once you have carried a light through the rain, you remember
that darkness is only a story waiting for a little glow"""

result = await translate_chunk_async(test_text)
print(f"Translation: {result}")
# Out:
# Translation: [{'type': 'text', 'text': 'ꯂꯧꯕꯨꯛ ꯃꯔꯛꯇꯥ ꯂꯩꯕꯥ ꯑꯄꯤꯛꯄꯥ ꯂꯝꯕꯤ ꯑꯃꯗꯥ, ꯑꯔꯖꯨꯟ ꯀꯧꯕꯥ ꯑꯉꯥꯡ ꯑꯃꯥ ꯅꯣꯡ ꯆꯨꯕꯗꯥ ꯌꯨꯝꯗꯥ ꯍꯜꯂꯛꯂꯝꯃꯤ꯫\nꯅꯣꯡꯂꯩ-ꯅꯨꯡꯁꯤꯠꯅꯥ ꯑꯇꯤꯌꯥꯕꯨ ꯀꯨꯞꯁꯤꯟꯈꯤ, ꯑꯃꯁꯨꯡ ꯈꯨꯉꯪꯒꯤ ꯃꯉꯥꯜꯁꯤꯡꯗꯨ ꯂꯥꯞꯅꯥ ꯂꯩꯕꯥ ꯊꯋꯥꯟꯃꯤꯆꯥꯁꯤꯡꯒꯨꯝꯅꯥ ꯎꯕꯥ ꯐꯪꯈꯤ꯫\nꯃꯍꯥꯛꯀꯤ ꯈꯨꯠꯇꯥ ꯀꯤꯕꯥ ꯅꯥꯎꯔꯤꯟ ꯑꯃꯒꯨꯝꯅꯥ ꯃꯉꯥꯜ ꯆꯦꯛꯆꯦꯛ ꯂꯥꯎꯕꯥ ꯐꯥꯅꯨꯁ ꯑꯤꯛꯄꯥ ꯑꯃꯥ ꯄꯥꯏꯔꯝꯃꯤ꯫\nꯑꯔꯖꯨꯟꯅ�
�ꯥ ꯑꯉꯛꯄꯥ ꯑꯃꯥ ꯎꯈꯤ꯫ ꯐꯥꯅꯨꯁꯀꯤ ꯃꯉꯥꯜ ꯇꯥꯕꯥ ꯃꯐꯝ ꯈꯨꯗꯤꯡꯃꯛꯇꯥ, ꯏꯁꯤꯡ ꯄꯨꯝꯂꯤꯕꯥ ꯃꯐꯝꯁꯤꯡ ꯑꯗꯨ ꯏꯁꯤꯡ ꯄꯨꯝꯕꯥ ꯑꯣꯏꯅꯥ ꯎꯈꯤꯗꯦ꯫\nꯃꯈꯣꯏꯁꯤꯡ ꯑꯗꯨ ꯑꯄꯤꯛꯄꯥ ꯃꯤꯇꯝꯁꯤꯡꯒꯨꯝꯅꯥ ꯎꯈꯤ, ꯃꯐꯝ ꯈꯨꯗꯤꯡꯃꯛꯇꯥ ꯑꯇꯤꯌꯥꯒꯤ ꯇꯣꯉꯥꯟ ꯇꯣꯉꯥꯟꯕꯥ ꯃꯃꯤꯁꯤꯡ ꯇꯥꯔꯝꯃꯤ꯫ ꯑꯃꯗꯥ ꯊꯋꯥꯟꯃꯤꯆꯥ ꯑꯃꯥ, ꯑꯇꯣꯞꯄꯥ ꯑꯃꯗꯥ ꯂꯩꯆꯤꯜ ꯑꯃꯥ, ꯑꯃꯁꯨꯡ ꯑꯇꯣꯞꯄꯥ 
# ...

# %%
import os
import asyncio
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

# Set your API Key here
os.environ["GOOGLE_API_KEY"] ="AIzaSyAkoVASsCpQP0qa6oCdfAMG6XjAI9ynis0"

async def translate_chunk_async(text: str, model_id: str = "gemini-3-flash-preview"):
    if not text.strip():
        return ""

    # Temperature 0.2 prevents the repetition loops you saw earlier
    llm = ChatGoogleGenerativeAI(model=model_id, temperature=0.2)

    system_instruction = (
        "You are a professional translator specializing in the Meitei Mayek script. "
        "CRITICAL: Do NOT use the Bengali script (ফানুস). "
        "ONLY use the authentic Meitei Mayek Unicode characters (ꯐꯥꯅꯨꯁ). "
        "\n\nExample Translation:"
        "\nEnglish: The lantern was not only lighting the road."
        "\nManipuri: ꯐꯥꯅꯨꯁ ꯑꯗꯨꯅꯥ ꯂꯝꯕꯤ ꯃꯉꯥꯜ ꯊꯣꯛꯍꯟꯕꯥ ꯈꯛꯇꯥ ꯅꯠꯇꯦ꯫"
    )

    prompt = ChatPromptTemplate.from_messages([
        ("system", system_instruction),
        ("human", "{text}") # Changed from static text to the variable
    ])
    
    chain = prompt | llm
    
    try:
        response = await chain.ainvoke({"text": text})
        return response.content
    except Exception as e:
        return f"Error: {str(e)}"
